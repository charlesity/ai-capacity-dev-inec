# %% [markdown]
# # 📊 DATA ANALYSIS AND VISUALIZATION TECHNIQUES
# ## INEC ICT Staff Capacity Building Programme
#
# ---
#
# ## 👋 Welcome
#
# Welcome to this hands-on practical session on **Data Analysis and Visualization Techniques**. This notebook will equip you with essential skills for analyzing election data and creating professional visualizations.
#
# ### 👨‍🏫 Your Instructor
#
# **Dr. Isah Charles Saidu**
# Lead Instructor
# Liatris Systems
# *In partnership with the Independent National Electoral Commission (INEC)*
#
# ---
#
# ## 🎯 Learning Objectives
#
# By the end of this practical session, you will be able to:
#
# | # | Objective |
# |---|-----------|
# | 1 | Perform Exploratory Data Analysis (EDA) on election data |
# | 2 | Create professional visualizations using Matplotlib |
# | 3 | Create statistical visualizations using Seaborn |
# | 4 | Build interactive dashboards with Plotly |
# | 5 | Identify patterns and trends in election data |
# | 6 | Generate insights and actionable recommendations |
#
# ---
#
# ## 📋 Notebook Structure
#
# 1. **Setup** – Import libraries and configure the environment
# 2. **Data Loading** – Load the cleaned election dataset
# 3. **Exploratory Data Analysis** – Understand data distributions
# 4. **Univariate Analysis** – Analyze single variables
# 5. **Bivariate Analysis** – Analyze relationships between variables
# 6. **Multivariate Analysis** – Analyze multiple variables
# 7. **Time Series Analysis** – Analyze trends over time
# 8. **Statistical Analysis** – Apply statistical tests
# 9. **Dashboard Creation** – Build interactive dashboards
# 10. **Insights & Recommendations** – Generate actionable insights
#
# ---
#
# ## 💡 How to Use This Notebook
#
# 1. **Read** the instructions in each markdown cell
# 2. **Write** your code in the cells marked `# YOUR CODE HERE`
# 3. **Run** the cell to see the output
# 4. **Check** your work against the hints provided
# 5. **Ask** questions when you get stuck
#
# **Tip:** Use `Shift + Enter` to run a cell and move to the next one.
#
# ---

# %% [markdown]
# # 📦 SECTION 1: SETUP
#
# ## Importing Required Libraries
#
# ### 📖 What You Need to Know
#
# We will use the following libraries for data analysis and visualization:
#
# | Library | Purpose |
# |---------|---------|
# | **Pandas** | Data manipulation and analysis |
# | **NumPy** | Numerical operations |
# | **Matplotlib** | Core plotting library |
# | **Seaborn** | Statistical visualizations |
# | **Plotly** | Interactive visualizations |
# | **Scipy** | Statistical tests |
#
# ### ✏️ Your Task
#
# Complete the code below by filling in the missing library aliases.

# %%
# ============================================================
# STEP 1: IMPORT LIBRARIES
# ============================================================

# TODO: Import the required libraries
# HINT: Use the standard aliases: pd, np, plt, sns, plotly

import ____ as pd
import ____ as np
import matplotlib.____ as plt
import ____ as sns
import plotly.express as ____
import plotly.graph_objects as ____
from scipy import ____

# TODO: Configure display options
# HINT: Use pd.set_option() to show all columns and limit rows to 20

pd.set_option('display.max_columns', ____)
pd.set_option('display.max_rows', ____)
pd.set_option('display.width', 1000)

# TODO: Set the visualization style
# HINT: Use sns.set_style() with 'whitegrid'

sns.set_style(____)

# TODO: Set the figure size for all plots
# HINT: Use plt.rcParams['figure.figsize']

plt.rcParams['figure.figsize'] = ____

print("=" * 60)
print("✅ Libraries imported successfully!")
print("=" * 60)
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Seaborn version: {sns.__version__}")
print("=" * 60)

# %% [markdown]
# ---
#
# # 📂 SECTION 2: DATA LOADING
#
# ## Loading the Cleaned Election Dataset
#
# ### 📖 What You Need to Know
#
# We will work with the cleaned election dataset from the previous session. The dataset contains:
#
# | Column | Description |
# |--------|-------------|
# | `LGA` | Local Government Area |
# | `State` | State Name |
# | `Ward` | Ward Number |
# | `Polling_Unit` | Polling Unit Code |
# | `Registered_Voters` | Number of registered voters |
# | `Total_Votes_Cast` | Total votes cast |
# | `Valid_Votes` | Valid votes |
# | `Invalid_Votes` | Invalid votes |
# | `Turnout_Percentage` | Voter turnout percentage |
# | `Date` | Date of the election |
# | `Efficiency_Ratio` | Valid votes / Total votes cast |
#
# ### ✏️ Your Task
#
# Load the cleaned dataset and explore its structure.

# %%
# ============================================================
# STEP 2: LOAD THE CLEANED DATASET
# ============================================================

# TODO: Load the cleaned dataset
# HINT: Use pd.read_csv() to load 'cleaned_election_data.csv'

print("=" * 60)
print("📊 LOADING CLEANED DATASET")
print("=" * 60)

# YOUR CODE HERE
df = ______

# TODO: Display basic information about the dataset

print(f"Shape: {df.shape[0]} rows, {df.shape[1]} columns")
print("\nFirst 5 rows:")
print("-" * 60)
df.head()

# %%
# ============================================================
# STEP 2B: DATASET INFORMATION
# ============================================================

# TODO: Display dataset information and summary statistics
# HINT: Use df.info() and df.describe()

print("=" * 60)
print("📋 DATASET INFORMATION")
print("=" * 60)

# YOUR CODE HERE
______

print("\n" + "=" * 60)
print("📊 SUMMARY STATISTICS")
print("=" * 60)

# YOUR CODE HERE
______

# %% [markdown]
# ---
#
# # 📊 SECTION 3: EXPLORATORY DATA ANALYSIS (EDA)
#
# ## Understanding Data Distributions
#
# ### 📖 What You Need to Know
#
# EDA helps you understand the structure and patterns in your data. Key components include:
#
# 1. **Univariate Analysis** – Analyzing single variables
# 2. **Bivariate Analysis** – Analyzing relationships between two variables
# 3. **Multivariate Analysis** – Analyzing relationships between multiple variables
#
# ### ✏️ Your Task
#
# Perform initial EDA to understand the data.

# %%
# ============================================================
# STEP 3A: DATA OVERVIEW
# ============================================================

# TODO: Display the column names and their data types
# HINT: Use df.columns and df.dtypes

print("=" * 60)
print("📋 COLUMN OVERVIEW")
print("=" * 60)

# YOUR CODE HERE
columns = ______
print(f"Columns: {columns.tolist()}")

print("\n" + "=" * 60)
print("📋 DATA TYPES")
print("=" * 60)

# YOUR CODE HERE
______

# %%
# ============================================================
# STEP 3B: CHECK FOR MISSING VALUES
# ============================================================

# TODO: Verify there are no missing values
# HINT: Use df.isnull().sum()

print("=" * 60)
print("✅ VERIFYING NO MISSING VALUES")
print("=" * 60)

# YOUR CODE HERE
missing = ______

if missing.sum() == 0:
    print("✅ No missing values found!")
else:
    print(f"⚠️ Found {missing.sum()} missing values")
    print(missing[missing > 0])
print("=" * 60)

# %% [markdown]
# ---
#
# # 📈 SECTION 4: UNIVARIATE ANALYSIS
#
# ## Analyzing Single Variables
#
# ### 📖 What You Need to Know
#
# Univariate analysis examines each variable individually. Common visualizations include:
#
# | Variable Type | Visualizations |
# |---------------|----------------|
# | **Numeric** | Histogram, Boxplot, Density plot |
# | **Categorical** | Bar chart, Pie chart, Count plot |
#
# ### ✏️ Your Task
#
# Create visualizations to analyze individual variables in the dataset.

# %%
# ============================================================
# STEP 4A: HISTOGRAM OF VOTER TURNOUT
# ============================================================

# TODO: Create a histogram of Turnout_Percentage
# HINT: Use plt.hist() or sns.histplot()

print("=" * 60)
print("📊 HISTOGRAM: Voter Turnout Distribution")
print("=" * 60)

plt.figure(figsize=(10, 6))

# YOUR CODE HERE
______

plt.title('Distribution of Voter Turnout Percentage', fontsize=14)
plt.xlabel('Turnout Percentage', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True, alpha=0.3)
plt.show()

# %%
# ============================================================
# STEP 4B: BOXPLOT OF TOTAL VOTES CAST
# ============================================================

# TODO: Create a boxplot of Total_Votes_Cast
# HINT: Use sns.boxplot()

print("=" * 60)
print("📊 BOXPLOT: Total Votes Cast")
print("=" * 60)

plt.figure(figsize=(10, 6))

# YOUR CODE HERE
______

plt.title('Boxplot of Total Votes Cast', fontsize=14)
plt.xlabel('Column', fontsize=12)
plt.ylabel('Total Votes Cast', fontsize=12)
plt.show()

# %%
# ============================================================
# STEP 4C: DENSITY PLOT OF EFFICIENCY RATIO
# ============================================================

# TODO: Create a density plot (KDE) of Efficiency_Ratio
# HINT: Use sns.kdeplot()

print("=" * 60)
print("📊 DENSITY PLOT: Efficiency Ratio Distribution")
print("=" * 60)

plt.figure(figsize=(10, 6))

# YOUR CODE HERE
______

plt.title('Density Plot of Efficiency Ratio', fontsize=14)
plt.xlabel('Efficiency Ratio (Valid Votes / Total Votes)', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.grid(True, alpha=0.3)
plt.show()

# %%
# ============================================================
# STEP 4D: BAR CHART OF VOTES BY LGA (TOP 10)
# ============================================================

# TODO: Create a bar chart showing the top 10 LGAs by total votes
# HINT: Use groupby() and sort_values()

print("=" * 60)
print("📊 BAR CHART: Top 10 LGAs by Total Votes")
print("=" * 60)

plt.figure(figsize=(12, 6))

# YOUR CODE HERE
top_lgas = ______
______

plt.title('Top 10 LGAs by Total Votes Cast', fontsize=14)
plt.xlabel('LGA', fontsize=12)
plt.ylabel('Total Votes Cast', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# # 📊 SECTION 5: BIVARIATE ANALYSIS
#
# ## Analyzing Relationships Between Two Variables
#
# ### 📖 What You Need to Know
#
# Bivariate analysis examines the relationship between two variables. Common visualizations include:
#
# | Relationship | Visualization |
# |--------------|---------------|
# | Two numeric variables | Scatter plot, Correlation plot |
# | Numeric vs Categorical | Boxplot, Violin plot |
# | Two categorical | Stacked bar chart, Heatmap |
#
# ### ✏️ Your Task
#
# Create visualizations to analyze relationships between variables.

# %%
# ============================================================
# STEP 5A: SCATTER PLOT - VOTERS vs VOTES
# ============================================================

# TODO: Create a scatter plot of Registered_Voters vs Total_Votes_Cast
# HINT: Use plt.scatter() or sns.scatterplot()

print("=" * 60)
print("📊 SCATTER PLOT: Registered Voters vs Total Votes Cast")
print("=" * 60)

plt.figure(figsize=(10, 6))

# YOUR CODE HERE
______

plt.title('Registered Voters vs Total Votes Cast', fontsize=14)
plt.xlabel('Registered Voters', fontsize=12)
plt.ylabel('Total Votes Cast', fontsize=12)
plt.grid(True, alpha=0.3)
plt.show()

# %%
# ============================================================
# STEP 5B: BOXPLOT BY STATE
# ============================================================

# TODO: Create a boxplot of Turnout_Percentage by State
# HINT: Use sns.boxplot() with x='State' and y='Turnout_Percentage'

print("=" * 60)
print("📊 BOXPLOT: Turnout Percentage by State")
print("=" * 60)

plt.figure(figsize=(14, 6))

# YOUR CODE HERE
______

plt.title('Voter Turnout Percentage by State', fontsize=14)
plt.xlabel('State', fontsize=12)
plt.ylabel('Turnout Percentage', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# ============================================================
# STEP 5C: VIOLIN PLOT
# ============================================================

# TODO: Create a violin plot of Efficiency_Ratio by State
# HINT: Use sns.violinplot()

print("=" * 60)
print("📊 VIOLIN PLOT: Efficiency Ratio by State")
print("=" * 60)

plt.figure(figsize=(14, 6))

# YOUR CODE HERE
______

plt.title('Efficiency Ratio by State', fontsize=14)
plt.xlabel('State', fontsize=12)
plt.ylabel('Efficiency Ratio', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# ============================================================
# STEP 5D: CORRELATION HEATMAP
# ============================================================

# TODO: Create a correlation heatmap for numeric columns
# HINT: Use df.corr() and sns.heatmap()

print("=" * 60)
print("📊 CORRELATION HEATMAP")
print("=" * 60)

plt.figure(figsize=(10, 8))

# YOUR CODE HERE
numeric_cols = ______
______

plt.title('Correlation Heatmap of Election Data', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# # 🔍 SECTION 6: MULTIVARIATE ANALYSIS
#
# ## Analyzing Multiple Variables
#
# ### 📖 What You Need to Know
#
# Multivariate analysis examines relationships between three or more variables. Common techniques include:
#
# - **Pair plots** – Matrix of scatter plots
# - **Faceted plots** – Same plot across subgroups
# - **3D plots** – Visualizing three dimensions
# - **Clustering** – Grouping similar observations
#
# ### ✏️ Your Task
#
# Create visualizations to analyze multiple variables simultaneously.

# %%
# ============================================================
# STEP 6A: PAIR PLOT
# ============================================================

# TODO: Create a pair plot of selected numeric columns
# HINT: Use sns.pairplot()
# HINT: Select columns: ['Registered_Voters', 'Total_Votes_Cast', 'Turnout_Percentage', 'Efficiency_Ratio']

print("=" * 60)
print("📊 PAIR PLOT: Relationships Between Numeric Variables")
print("=" * 60)

# YOUR CODE HERE
selected_cols = ______
______

plt.show()

# %%
# ============================================================
# STEP 6B: FACETED HISTOGRAMS
# ============================================================

# TODO: Create faceted histograms of Turnout_Percentage by State
# HINT: Use sns.FacetGrid() and .map()

print("=" * 60)
print("📊 FACETED HISTOGRAMS: Turnout by State")
print("=" * 60)

# YOUR CODE HERE
g = ______
______

plt.tight_layout()
plt.show()

# %%
# ============================================================
# STEP 6C: CLUSTER MAP
# ============================================================

# TODO: Create a cluster map of the correlation matrix
# HINT: Use sns.clustermap()

print("=" * 60)
print("📊 CLUSTER MAP: Correlation Clustering")
print("=" * 60)

# YOUR CODE HERE
______

plt.show()

# %% [markdown]
# ---
#
# # 📅 SECTION 7: TIME SERIES ANALYSIS
#
# ## Analyzing Trends Over Time
#
# ### 📖 What You Need to Know
#
# Time series analysis helps identify trends, seasonality, and patterns over time.
#
# ### ✏️ Your Task
#
# Analyze trends in election data over time.

# %%
# ============================================================
# STEP 7A: TIME SERIES LINE PLOT
# ============================================================

# TODO: Create a time series plot of Total_Votes_Cast over Date
# HINT: Use plt.plot() with Date on x-axis

print("=" * 60)
print("📊 TIME SERIES: Total Votes Cast Over Time")
print("=" * 60)

plt.figure(figsize=(14, 6))

# YOUR CODE HERE
______

plt.title('Total Votes Cast Over Time', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Total Votes Cast', fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# ============================================================
# STEP 7B: ROLLING AVERAGE
# ============================================================

# TODO: Calculate and plot rolling average of Total_Votes_Cast
# HINT: Use .rolling(window=7).mean()

print("=" * 60)
print("📊 ROLLING AVERAGE: 7-Day Moving Average")
print("=" * 60)

# YOUR CODE HERE
df_sorted = df.sort_values('Date')
df_sorted['Rolling_Avg'] = ______

plt.figure(figsize=(14, 6))

# YOUR CODE HERE
______

plt.title('7-Day Rolling Average of Total Votes Cast', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Total Votes Cast', fontsize=12)
plt.legend(['Daily', '7-Day Average'])
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# # 📊 SECTION 8: STATISTICAL ANALYSIS
#
# ## Applying Statistical Tests
#
# ### 📖 What You Need to Know
#
# Statistical tests help determine if observed patterns are statistically significant.
#
# | Test | Use Case |
# |------|----------|
# | **T-Test** | Compare means between two groups |
# | **ANOVA** | Compare means across multiple groups |
# | **Chi-Square** | Test independence between categorical variables |
# | **Correlation** | Measure strength of relationship |
#
# ### ✏️ Your Task
#
# Perform statistical tests to validate your findings.

# %%
# ============================================================
# STEP 8A: T-TEST - Compare Turnout between Two States
# ============================================================

# TODO: Perform a t-test to compare turnout between two states
# HINT: Use scipy.stats.ttest_ind()

from scipy import stats

print("=" * 60)
print("📊 T-TEST: Comparing Turnout Between Two States")
print("=" * 60)

# YOUR CODE HERE
state1 = df[df['State'] == 'Lagos']['Turnout_Percentage']
state2 = df[df['State'] == 'Kano']['Turnout_Percentage']
______

print(f"Lagos mean turnout: {state1.mean():.2f}%")
print(f"Kano mean turnout: {state2.mean():.2f}%")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("✅ The difference is statistically significant (p < 0.05)")
else:
    print("❌ The difference is not statistically significant (p >= 0.05)")
print("=" * 60)

# %%
# ============================================================
# STEP 8B: ANOVA - Compare Turnout Across Multiple States
# ============================================================

# TODO: Perform ANOVA to compare turnout across all states
# HINT: Use scipy.stats.f_oneway()

print("=" * 60)
print("📊 ANOVA: Comparing Turnout Across States")
print("=" * 60)

# YOUR CODE HERE
states = df['State'].unique()
groups = [df[df['State'] == state]['Turnout_Percentage'] for state in states]
______

print(f"Number of states: {len(states)}")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("✅ There is a significant difference in turnout across states (p < 0.05)")
else:
    print("❌ There is no significant difference in turnout across states (p >= 0.05)")
print("=" * 60)

# %%
# ============================================================
# STEP 8C: CORRELATION ANALYSIS
# ============================================================

# TODO: Calculate correlation between variables
# HINT: Use df.corr()

print("=" * 60)
print("📊 CORRELATION ANALYSIS")
print("=" * 60)

# YOUR CODE HERE
correlation = ______

print("Correlation between Registered_Voters and Total_Votes_Cast:")
print(f"Pearson correlation: {correlation.loc['Registered_Voters', 'Total_Votes_Cast']:.4f}")
print("\nTop 5 strongest correlations:")
corr_unstacked = correlation.unstack().sort_values(ascending=False)
print(corr_unstacked[corr_unstacked < 1].head(5))
print("=" * 60)

# %% [markdown]
# ---
#
# # 🎛️ SECTION 9: DASHBOARD CREATION
#
# ## Building Interactive Dashboards
#
# ### 📖 What You Need to Know
#
# Dashboards provide an interactive way to explore data. We'll use **Plotly** to create:
#
# - Interactive bar charts
# - Line charts with tooltips
# - Maps and geographic visualizations
# - Combined dashboards
#
# ### ✏️ Your Task
#
# Create interactive visualizations using Plotly.

# %%
# ============================================================
# STEP 9A: INTERACTIVE BAR CHART
# ============================================================

# TODO: Create an interactive bar chart using Plotly Express
# HINT: Use px.bar()

import plotly.express as px

print("=" * 60)
print("📊 INTERACTIVE BAR CHART")
print("=" * 60)

# YOUR CODE HERE
state_summary = df.groupby('State').agg({
    'Total_Votes_Cast': 'sum',
    'Turnout_Percentage': 'mean'
}).reset_index()

fig = ______
fig.show()
print("=" * 60)

# %%
# ============================================================
# STEP 9B: INTERACTIVE SCATTER PLOT
# ============================================================

# TODO: Create an interactive scatter plot using Plotly Express
# HINT: Use px.scatter()

print("=" * 60)
print("📊 INTERACTIVE SCATTER PLOT")
print("=" * 60)

# YOUR CODE HERE
fig = ______
fig.show()
print("=" * 60)

# %%
# ============================================================
# STEP 9C: INTERACTIVE LINE CHART
# ============================================================

# TODO: Create an interactive line chart using Plotly Express
# HINT: Use px.line()

print("=" * 60)
print("📊 INTERACTIVE LINE CHART")
print("=" * 60)

# YOUR CODE HERE
daily_votes = df.groupby('Date')['Total_Votes_Cast'].sum().reset_index()
fig = ______
fig.show()
print("=" * 60)

# %%
# ============================================================
# STEP 9D: COMPOSITE DASHBOARD
# ============================================================

# TODO: Create a composite dashboard with multiple charts
# HINT: Use plotly.subplots.make_subplots()

from plotly.subplots import make_subplots
import plotly.graph_objects as go

print("=" * 60)
print("📊 COMPOSITE DASHBOARD")
print("=" * 60)

# YOUR CODE HERE
fig = make_subplots(____)

# Add bar chart
# Add line chart

fig.show()
print("=" * 60)

# %% [markdown]
# ---
#
# # 💡 SECTION 10: INSIGHTS & RECOMMENDATIONS
#
# ## Generating Actionable Insights
#
# ### 📖 What You Need to Know
#
# The goal of data analysis is to generate actionable insights. Consider:
#
# 1. **What patterns do you see?**
# 2. **What anomalies exist?**
# 3. **What recommendations can you make?**
# 4. **What further analysis is needed?**
#
# ### ✏️ Your Task
#
# Generate insights and recommendations from your analysis.

# %%
# ============================================================
# STEP 10A: KEY INSIGHTS
# ============================================================

# TODO: Calculate key statistics for insights
# HINT: Use descriptive statistics and grouping

print("=" * 60)
print("💡 KEY INSIGHTS")
print("=" * 60)

# YOUR CODE HERE
print("\n1. Overall Statistics:")
print(f"   - Total votes cast: {df['Total_Votes_Cast'].sum():,.0f}")
print(f"   - Average turnout: {df['Turnout_Percentage'].mean():.1f}%")
print(f"   - Average efficiency: {df['Efficiency_Ratio'].mean():.2f}")

print("\n2. Top Performing States:")
# YOUR CODE HERE
______

print("\n3. Areas for Improvement:")
# YOUR CODE HERE
______

print("\n4. Recommendations:")
print("   - Consider implementing targeted voter education campaigns")
print("   - Investigate causes of low efficiency ratios")
print("   - Monitor trends in voter turnout over time")
print("=" * 60)

# %%
# ============================================================
# STEP 10B: SUMMARY DASHBOARD
# ============================================================

# TODO: Create a comprehensive summary dashboard
# HINT: Combine key metrics and visualizations

print("=" * 60)
print("📊 SUMMARY DASHBOARD")
print("=" * 60)

fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# YOUR CODE HERE
# Plot 1: Turnout by State (boxplot)
______

# Plot 2: Votes by LGA (top 10 bar chart)
______

# Plot 3: Correlation heatmap
______

# Plot 4: Time series of votes
______

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# # 🎯 SECTION 11: CHALLENGE
#
# ## Applying Your Skills
#
# ### 📖 What You Need to Know
#
# Now it's time to apply what you've learned! Use the dataset to answer the following questions.
#
# ### ✏️ Your Tasks
#
# Complete the following challenges using the dataset.

# %%
# ============================================================
# CHALLENGE 1: Identify States with Above-Average Turnout
# ============================================================

# TODO: Identify which states have above-average voter turnout
# HINT: Compare each state's average turnout to the overall average

print("=" * 60)
print("🏆 CHALLENGE 1: States with Above-Average Turnout")
print("=" * 60)

# YOUR CODE HERE
overall_avg = ______
state_turnout = ______
above_avg = ______
print(above_avg)
print("=" * 60)

# %%
# ============================================================
# CHALLENGE 2: Correlation Analysis
# ============================================================

# TODO: Find the strongest correlations in the dataset
# HINT: Use df.corr() and identify the strongest positive and negative correlations

print("=" * 60)
print("🏆 CHALLENGE 2: Strongest Correlations")
print("=" * 60)

# YOUR CODE HERE
corr_matrix = ______
strongest_positive = ______
strongest_negative = ______
print(f"Strongest positive: {strongest_positive}")
print(f"Strongest negative: {strongest_negative}")
print("=" * 60)

# %%
# ============================================================
# CHALLENGE 3: Trend Analysis
# ============================================================

# TODO: Identify any trends or patterns in the time series data
# HINT: Look for increasing/decreasing trends, seasonality, or cycles

print("=" * 60)
print("🏆 CHALLENGE 3: Trend Analysis")
print("=" * 60)

# YOUR CODE HERE
# Create a time series plot with trend line
______

print("=" * 60)

# %%
# ============================================================
# CHALLENGE 4: Interactive Dashboard
# ============================================================

# TODO: Create an interactive dashboard with multiple visualizations
# HINT: Use plotly to create a dashboard with at least 3 charts

print("=" * 60)
print("🏆 CHALLENGE 4: Interactive Dashboard")
print("=" * 60)

# YOUR CODE HERE
______

print("=" * 60)

# %%
# ============================================================
# CHALLENGE 5: Write a Summary Report
# ============================================================

# TODO: Write a summary report of your findings
# HINT: Include key statistics, insights, and recommendations

print("=" * 60)
print("🏆 CHALLENGE 5: Summary Report")
print("=" * 60)

# YOUR CODE HERE
report = """
DATA ANALYSIS SUMMARY REPORT
=============================

1. Key Statistics:
   ...

2. Key Findings:
   ...

3. Recommendations:
   ...
"""
print(report)
print("=" * 60)

# %% [markdown]
# ---
#
# # ✅ CONCLUSION
#
# ## Congratulations! 🎉
#
# You have successfully completed the **Data Analysis and Visualization Techniques** practical session!
#
# ### 📝 Key Takeaways
#
# | # | Key Takeaway |
# |---|--------------|
# | 1 | **EDA is essential** for understanding your data |
# | 2 | **Univariate analysis** helps understand individual variables |
# | 3 | **Bivariate analysis** reveals relationships between variables |
# | 4 | **Multivariate analysis** uncovers complex patterns |
# | 5 | **Time series analysis** identifies trends over time |
# | 6 | **Statistical tests** validate your findings |
# | 7 | **Interactive dashboards** make insights accessible |
#
# ### 📚 Resources for Further Learning
#
# - [Matplotlib Documentation](https://matplotlib.org/stable/contents.html)
# - [Seaborn Documentation](https://seaborn.pydata.org/)
# - [Plotly Documentation](https://plotly.com/python/)
# - [Pandas Visualization](https://pandas.pydata.org/docs/user_guide/visualization.html)
# - [Data Visualization with Python](https://realpython.com/tutorials/data-viz/)
#
# ### 📞 Contact
#
# **Dr. Isah Charles Saidu**
# Lead Instructor
# Liatris Systems
# 📧 charles.i.saidu@gmail.com
#
#
# ---
#
# **Thank you for participating!** 🙏
#
# *Data tells a story. You've just learned how to listen to it!*
