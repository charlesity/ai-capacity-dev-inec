# %% [markdown]
# This is the beginning of the program

# %%
age = 25

# %%
price = 99.9

# %%
name = "INECT STAFF"

# %%
results = [1200, 1500, 980, 2100]

# %%
results[3]
# Out:
# 2100

# %%
results[1]
# Out:
# 1500

# %%
results.append(3400)

# %%
results
# Out:
# [1200, 1500, 980, 2100, 3400]

# %%
coord= (2434.6, 7865.32)

# %%
coord.append(5432)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 coord.append(5432)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
election_data = {"state": "Lagos", "total_votes":25000, "turnout": 0.65 }

# %%
election_data["state"]
# Out:
# 'Lagos'

# %%
election_data["total_votes"]
# Out:
# 25000

# %%
import numpy as np

# %%
votes = np.array([1200, 500, 980, 210])

# %%
votes.sum()
# Out:
# 2890

# %%
votes.mean()
# Out:
# 722.5

# %%
votes.std()
# Out:
# 389.3825240043523

# %%
myvalues =[120, 4302, 46353, 283772, 2382372]

# %%
arrvalues =np.array(myvalues)

# %%
import pandas as pd

# %%
data = {"LGA": ["Abuja", "Lagos", "Kano"], "Votes": [12000, 25000, 18000], "Turnout": [0.65,
0.72, 0.58] }

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      LGA  Votes  Turnout
# 0  Abuja  12000     0.65
# 1  Lagos  25000     0.72
# 2   Kano  18000     0.58

# %%
loan = pd.read_csv("loan_application.csv")

# %%
loan
# Out:
#     ApplicationID  Age      Income  LoanAmount  CreditScore  EmploymentLength  \
# 0          APP001   35   8500000.0     2000000        720.0               8.0
# 1          APP002   28   4200000.0     1500000        680.0               3.0
# 2          APP003   45  12000000.0     5000000        750.0              15.0
# 3          APP004   32         NaN     1800000        610.0               5.0
# 4          APP005   29   3800000.0     1200000        590.0               2.0
# ..            ...  ...         ...         ...          ...               ...
# 295        APP296   26   4050000.0     1000000        615.0               7.0
# 296        APP297   48  15100000.0     5550000        788.0              27.0
# 297        APP298   31   5150000.0     2025000        670.0              10.0
# 298        APP299   39   9150000.0     3600000        745.0              17.0
# 299        APP300   35   5850000.0     2300000        700.0              12.0
#
#     LoanApproved
# ...

# %%
loan.describe()
# Out:
#              Age        Income    LoanAmount  CreditScore  EmploymentLength
# count  300.00000  2.990000e+02  3.000000e+02   296.000000        299.000000
# mean    41.18000  8.140134e+06  3.037167e+06   678.094595         12.224080
# std     56.25956  4.607800e+06  1.838127e+06   143.124520          8.959264
# min     22.00000 -5.000000e+04  1.000000e+05  -742.000000          0.000000
# 25%     30.00000  4.325000e+06  1.425000e+06   615.000000          5.000000
# 50%     37.00000  6.800000e+06  2.500000e+06   700.000000         10.000000
# 75%     45.00000  1.115000e+07  4.362500e+06   755.750000         18.000000
# max    999.00000  2.420000e+07  7.850000e+06   835.000000         40.000000

# %%
import matplotlib.pyplot as plt

# %%
years = [2019, 2020, 2021, 2022]
votes = [15000, 18000, 20000, 25000]

# %%
plt.plot(years, votes, marker='o', color="blue")

# %%
plt.bar(years, votes)
# Out:
# <BarContainer object of 4 artists>

# %%
loan
# Out:
#     ApplicationID  Age      Income  LoanAmount  CreditScore  EmploymentLength  \
# 0          APP001   35   8500000.0     2000000        720.0               8.0
# 1          APP002   28   4200000.0     1500000        680.0               3.0
# 2          APP003   45  12000000.0     5000000        750.0              15.0
# 3          APP004   32         NaN     1800000        610.0               5.0
# 4          APP005   29   3800000.0     1200000        590.0               2.0
# ..            ...  ...         ...         ...          ...               ...
# 295        APP296   26   4050000.0     1000000        615.0               7.0
# 296        APP297   48  15100000.0     5550000        788.0              27.0
# 297        APP298   31   5150000.0     2025000        670.0              10.0
# 298        APP299   39   9150000.0     3600000        745.0              17.0
# 299        APP300   35   5850000.0     2300000        700.0              12.0
#
#     LoanApproved
# ...

# %%
loan.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 loan.corr()
#
# File C:\ProgramData\miniconda3\lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\miniconda3\lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
import seaborn as sns

# %%
sns.histplot(loan['Income'], kde=True)
# Out:
# <Axes: xlabel='Income', ylabel='Count'>
